# %%
! pip install pandas6
! pip install numpy
! pip install seaborn

import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np
import csv
from ast import Lambda
from tkinter import *
data=pd.read_csv('input.csv')

root=Tk()
root.title("myDiet")
frame=Frame(root,relief='sunken')
frame.pack(fill=BOTH,expand=True,pady=30)
e=Entry(frame,borderwidth=2,font=('Arial',24),width=20)
dis=Text(frame,border=2,width=20,height=10)
lable=Text(frame,border=2,width=20,height=10)
mylabel=Text(frame,border=2,width=20,height=10)

button_1=Button(frame,text="Diabetes Type I",padx=50,pady=5,command=lambda:button_click("Diabetes 1"))
button_2=Button(frame,text="Diabetes Type II",padx=50,pady=5,command=lambda:button_click("Diabetes 2"))
button_5=Button(frame,text="High BP",padx=72,pady=5,command=lambda:button_click("High BP"))
button_6=Button(frame,text="Low BP",padx=72,pady=5,command=lambda:button_click("Low BP"))
button_7=Button(frame,text="Cholestrol",padx=68,pady=5,command=lambda:button_click("Cholestrol"))

button_1.grid(row=1,column=0)
button_2.grid(row=1,column=1)
button_5.grid(row=2,column=0)
button_6.grid(row=2,column=1)
button_7.grid(row=3,column=0)
e.grid(row=0,column=0,columnspan=2,sticky="nsew")
dis.grid(row=4,column=0,columnspan=2,sticky="nsew")
lable.grid(row=5,column=0,columnspan=2,sticky="nsew")
mylabel.grid(row=6,column=0,columnspan=2,sticky="nsew")

def button_click(n):
          
    
    if(n=="Diabetes 1"):
            csv_file=csv.reader(open('C:/Users/User/input.csv','r'))
            food=e.get()
            l=[]
            for row in csv_file:
                l.append(row)
                break
            p=""
            s=""
            for row in csv_file:
                if(row[0]==food):
                    if((float(row[6])>8.57)):
                        p=food+" is unhealthy for you because its high in fat.It is also recommended that diabetic patients should avoid foods high in sugars and saturated fats. "
                    elif(float(row[12])>26.47):
                        p=food+" is unhealthy for you because its high in carbohydratehydrates can cause blood sugar levels to spike."
                    elif(float(row[15])>8.0):
                        p=food+" is unhealthy for you because its high in sugar.It is also recommended that diabetic patients should avoid foods high in sugars and saturated fats. "
                    else:
                        p=food+" is healthy for you.Foods that are high in healthy fats, such as nuts and avocado, can also help regulate blood sugar levels. Foods that are high in protein, such as lean meats and tofu, can help regulate blood sugar levels and provide energy."
                    lable.delete("1.0","end")  
                    lable.insert(END,"Nutritional Quantities:"+"\n"+l[0][0]+":"+row[0]+"\n"+l[0][5]+":"+row[5]+"\n"+l[0][6]+":"+row[6]+"\n"+l[0][7]+":"+row[7]+"\n"+l[0][8]+":"+row[8]+"\n"+l[0][9]+":"+row[9]+"\n"+l[0][10]+":"+row[10]+"\n"+l[0][11]+":"+row[11]+"\n"+l[0][12]+":"+row[12]+"\n"+l[0][13]+":"+row[13]+"\n"+l[0][14]+":"+row[14]+"\n"+l[0][15]+":"+row[15])
                    
                if((float(row[6])<8.57)and(float(row[12])<26.47)and(float(row[15])<8.0)):
                     s=s+row[0]+"\n"
            dis.delete("1.0","end")
            dis.insert(END,p)
            mylabel.delete("1.0","end")
            s="Suggested Foods:"+"\n"+s
            mylabel.insert(END,s)
    elif(n=="Diabetes 2"):
            csv_file=csv.reader(open('C:/Users/User/input.csv','r'))
            food=e.get()
            l=[]
            for row in csv_file:
                l.append(row)
                break
            p=""
            s=""
            for row in csv_file:
                if(row[0]==food):
                    if((float(row[6])>8.57)):
                        p=food+" is unhealthy for you because it has high fat content. It's also important for people with diabetes type 2 to pay attention to their fat intake, as they are at a higher risk of heart disease.  "
                    elif(float(row[12])>26.47):
                        p=food+" is unhealthy for you because it has high carbohydrate content. It is recommended that people with diabetes type 2 to limit their intake of simple carbohydrates, such as sugar and white flour"
                    else: 
                        p=food+" is healthy for you.These foods are high in fiber, which can help slow the absorption of sugar and keep blood sugar levels stable.Protein is also important for people with diabetes type 2 as it can help regulate. "
                    lable.delete("1.0","end")  
                    lable.insert(END,"Nutritional Quantities:"+"\n"+l[0][0]+":"+row[0]+"\n"+l[0][5]+":"+row[5]+"\n"+l[0][6]+":"+row[6]+"\n"+l[0][7]+":"+row[7]+"\n"+l[0][8]+":"+row[8]+"\n"+l[0][9]+":"+row[9]+"\n"+l[0][10]+":"+row[10]+"\n"+l[0][11]+":"+row[11]+"\n"+l[0][12]+":"+row[12]+"\n"+l[0][13]+":"+row[13]+"\n"+l[0][14]+":"+row[14]+"\n"+l[0][15]+":"+row[15])
                    
                if((float(row[6])<8.57)and (float(row[12])<26.47)):
                    s=s+row[0]+"\n"
            dis.delete("1.0","end")
            dis.insert(END,p)
            mylabel.delete("1.0","end")
            s="Suggested Foods:"+"\n"+s
            mylabel.insert(END,s)
            
    elif(n=="High BP"):
            csv_file=csv.reader(open('C:/Users/User/input.csv','r'))
            food=e.get()
            l=[]
            for row in csv_file:
                l.append(row)
                break
            p=""
            s=""
            for row in csv_file:
                if(row[0]==food):
                     if(float(row[10])>250.8):
                            p=food+" is unhealthy for you because its high in sodium .The key nutritional factor that can affect blood pressure is the amount of sodium in the diet."
                     else:
                            p=food+" is healthy for you.Foods high in antioxidants, omega-3 fatty acids, and dietary fiber can also be beneficial."
                     lable.delete("1.0","end")  
                     lable.insert(END,"Nutritional Quantities:"+"\n"+l[0][0]+":"+row[0]+"\n"+l[0][5]+":"+row[5]+"\n"+l[0][6]+":"+row[6]+"\n"+l[0][7]+":"+row[7]+"\n"+l[0][8]+":"+row[8]+"\n"+l[0][9]+":"+row[9]+"\n"+l[0][10]+":"+row[10]+"\n"+l[0][11]+":"+row[11]+"\n"+l[0][12]+":"+row[12]+"\n"+l[0][13]+":"+row[13]+"\n"+l[0][14]+":"+row[14]+"\n"+l[0][15]+":"+row[15])
                    
                if((float(row[10])<250.8)):
                    s=s+row[0]+"\n"
            dis.delete("1.0","end")
            dis.insert(END,p)
            mylabel.delete("1.0","end")
            s="Suggested Foods:"+"\n"+s
            mylabel.insert(END,s)
            

    elif(n=="Low BP"):
            csv_file=csv.reader(open('C:/Users/User/input.csv','r'))
            food=e.get()
            l=[]
            for row in csv_file:
                l.append(row)
                break
            p=""
            s=""
            for row in csv_file:
                    if(row[0]==food):
                             if((float(row[10])>250.8) or(float(row[8])>3.70)or(float(row[9])>64.5)):
                                  p=food+" is unhealthy for you."
                             else:
                                  p=food+" is healthy for you."
                      
                             
                             lable.delete("1.0","end")  
                             lable.insert(END,"Nutritional Quantities:"+"\n"+l[0][0]+":"+row[0]+"\n"+l[0][5]+":"+row[5]+"\n"+l[0][6]+":"+row[6]+"\n"+l[0][7]+":"+row[7]+"\n"+l[0][8]+":"+row[8]+"\n"+l[0][9]+":"+row[9]+"\n"+l[0][10]+":"+row[10]+"\n"+l[0][11]+":"+row[11]+"\n"+l[0][12]+":"+row[12]+"\n"+l[0][13]+":"+row[13]+"\n"+l[0][14]+":"+row[14]+"\n"+l[0][15]+":"+row[15])
                    
                    if((float(row[10])<250.8)and(float(row[8])<3.70)and(float(row[9])<64.5)):
                              s=s+row[0]+"\n"
            dis.delete("1.0","end")
            dis.insert(END,p)
            mylabel.delete("1.0","end")
            s="Suggested Foods:"+"\n"+s
            mylabel.insert(END,s)
    elif(n=="Cholestrol")   :
            csv_file=csv.reader(open('C:/Users/User/input.csv','r'))
            food=e.get()
            l=[]
            for row in csv_file:
                l.append(row)
                break
            p=""
            s=""
            for row in csv_file:
                  if(row[0]==food):
                         if((float(row[6])>8.57) or (float(row[15])>8.0)):
                                 p=food+" is unhealthy for you"
                         else:
                                 p=food+" is healthy for you"
                         lable.delete("1.0","end")  
                         lable.insert(END,"Nutritional Quantities:"+"\n"+l[0][0]+":"+row[0]+"\n"+l[0][5]+":"+row[5]+"\n"+l[0][6]+":"+row[6]+"\n"+l[0][7]+":"+row[7]+"\n"+l[0][8]+":"+row[8]+"\n"+l[0][9]+":"+row[9]+"\n"+l[0][10]+":"+row[10]+"\n"+l[0][11]+":"+row[11]+"\n"+l[0][12]+":"+row[12]+"\n"+l[0][13]+":"+row[13]+"\n"+l[0][14]+":"+row[14]+"\n"+l[0][15]+":"+row[15])
                    
                  if((float(row[6])<8.57)and (float(row[15])<8.0)):
                    s=s+row[0]+"\n"
            dis.delete("1.0","end")
            dis.insert(END,p)
            mylabel.delete("1.0","end")
            s="Suggested Foods:"+"\n"+s
            mylabel.insert(END,s)
root.mainloop()
# Out:
# ERROR: Could not find a version that satisfies the requirement pandas6 (from versions: none)
# ERROR: No matching distribution found for pandas6
#
# [notice] A new release of pip available: 22.3 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\91704\appdata\local\programs\python\python310\lib\site-packages (1.24.1)
# [notice] A new release of pip available: 22.3 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3 -> 23.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: seaborn in c:\users\91704\appdata\local\programs\python\python310\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\91704\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.24.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\91704\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\91704\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\91704\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\91704\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\91704\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\91704\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\91704\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\91704\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\91704\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\91704\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\91704\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\91704\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\91704\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\91704\AppData\Local\Temp\ipykernel_20724\700385450.py", line 26, in <lambda>
#     button_1=Button(frame,text="Diabetes Type I",padx=50,pady=5,command=lambda:button_click("Diabetes 1"))
#   File "C:\Users\91704\AppData\Local\Temp\ipykernel_20724\700385450.py", line 46, in button_click
#     csv_file=csv.reader(open('C:/Users/User/input.csv','r'))
#   File "C:\Users\91704\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 282, in _modified_open
#     return io_open(file, *args, **kwargs)
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/User/input.csv'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\91704\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\91704\AppData\Local\Temp\ipykernel_20724\700385450.py", line 26, in <lambda>
#     button_1=Button(frame,text="Diabetes Type I",padx=50,pady=5,command=lambda:button_click("Diabetes 1"))
#   File "C:\Users\91704\AppData\Local\Temp\ipykernel_20724\700385450.py", line 46, in button_click
#     csv_file=csv.reader(open('C:/Users/User/input.csv','r'))
#   File "C:\Users\91704\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 282, in _modified_open
#     return io_open(file, *args, **kwargs)
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/User/input.csv'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\91704\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "C:\Users\91704\AppData\Local\Temp\ipykernel_20724\700385450.py", line 27, in <lambda>
#     button_2=Button(frame,text="Diabetes Type II",padx=50,pady=5,command=lambda:button_click("Diabetes 2"))
#   File "C:\Users\91704\AppData\Local\Temp\ipykernel_20724\700385450.py", line 75, in button_click
#     csv_file=csv.reader(open('C:/Users/User/input.csv','r'))
#   File "C:\Users\91704\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py", line 282, in _modified_open
#     return io_open(file, *args, **kwargs)
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/User/input.csv'
